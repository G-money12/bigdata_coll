# %% [markdown]
# # 2. 웹 크롤링
#
# 웹 페이지 콘텐츠 요청 - urllib 패키지 활용
#
# 웹 페이지 콘텐츠 요청 - requests 패키지 활용
#
# 정적 라이브러리 : Beautifulsoup, Scrapy
#
# 동적 라이브러리 : selenium

# %%
import urllib.request

res=urllib.request.urlopen('http://www.naver.com')
print(type(res))
print(res.status)
print(res.version)
print(res.msg)
print(res.reason)
headers=res.getheaders()
for header in headers:
    print(header)

body=res.read()
print(body.decode('utf-8'))
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# 11
# OK
# OK
# ('Date', 'Wed, 05 Mar 2025 00:19:03 GMT')
# ('content-type', 'text/html; charset=UTF-8')
# ('transfer-encoding', 'chunked')
# ('set-cookie', 'PM_CK_loc=6a99d2fc1b5471d9d14cea36ec9cb8cce9f1e2f27a0a03ebb3406fdb4c4d0f32; Expires=Thu, 06 Mar 2025 00:19:03 GMT; Path=/; HttpOnly')
# ('cache-control', 'no-cache, no-store, must-revalidate')
# ('pragma', 'no-cache')
# ('x-frame-options', 'DENY')
# ('x-xss-protection', '1; mode=block')
# ('strict-transport-security', 'max-age=63072000; includeSubdomains')
# ('referrer-policy', 'unsafe-url')
# ('server', 'nfront')
# ('connection', 'close')
# ...

# %%
from urllib.request import urlopen
res=urlopen('http://www.naver.com')
print(res.read().decode('utf-8'))
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %%
import urllib.request as req
res=req.urlopen('http://www.naver.com')         # 엘리어스.urlopen
print(res.read().decode('utf-8'))
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %% [markdown]
# 예외처리

# %%
from urllib.error import HTTPError, URLError
try:
    res=req.urlopen('http://www.naver.com/none')
# except HTTPError as e:                        # 엘리어스.HTTPError
#     print(e.code)
#     print(e.reason)
#     print('HTTPError')
except URLError as e:
    print(e.reason)
    print('URLError')
else:
    print('Success')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 3
#       1 from urllib.error import HTTPError, URLError
#       2 try:
# ----> 3     res=req.urlopen('http://www.naver.com/none')
#       4 # except HTTPError as e:                        # 엘리어스.HTTPError
#       5 #     print(e.code)
#       6 #     print(e.reason)
#       7 #     print('HTTPError')
#       8 except URLError as e:
#
# AttributeError: 'HTTPResponse' object has no attribute 'urlopen'

# %% [markdown]
# 주요 모듈 활용

# %%
req=req.urlopen('http://www.naver.com')
print(req.read().decode('utf-8'))
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %%
import urllib.request as req
url='http://unico2013.dothome.co.kr/crawling/tagstyle.html'
req=req.urlopen(url)
print(res.read().decode('utf-8'))

# %% [markdown]
# 웹 페이지의 문자 셋 정보를 파이썬 프로그램으로도 파악할 수 있음

# %%
import urllib.request as req
url='http://www.naver.com'
res=req.urlopen(url)
a=res.info()
print(type(a))
encoding=a.get_content_charset()
print(encoding)
print(res.read().decode(encoding))
# Out:
# <class 'http.client.HTTPMessage'>
# utf-8
# ...

# %% [markdown]
# get_content_charset() 함수 사용 인코딩 정보 확인

# %%
import urllib.request
print("=======================================================")
url='https://www.python.org/'
f=urllib.request.urlopen(url)
print(type(f))
print(type(f.info()))
encoding=f.info().get_content_charset()
print(url,'페이지의 인코딩 정보 :',encoding)
text=f.read(500).decode(encoding)
print(text)
print("=======================================================")

url = 'https://www.google.com/'
f=urllib.request.urlopen(url)
encoding=f.info().get_content_charset()
print(url,'페이지의 인코딩 정보 :', endcoding)
text=f.read(500).decode(encoding)
print(text)
print("=======================================================")
# Out:
# ...
# <class 'http.client.HTTPResponse'>
# <class 'http.client.HTTPMessage'>
# https://www.python.org/ 페이지의 인코딩 정보 : utf-8
# <!doctype html>
# <!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->
# <!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->
# <!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->
# <!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->
#
# <head>
#     <!-- Google tag (gtag.js) -->
#     <script async src="https://www.googletagmanager.com/gtag/js?id=G-TF35YF9CVH"></script>
#     <script>
#       window.d
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 16
#      14 f=urllib.request.urlopen(url)
#      15 encoding=f.info().get_content_charset()
# ---> 16 print(url,'페이지의 인코딩 정보 :', endcoding)
# ...

# %% [markdown]
# url.parse : 주소를 각각의 변수로 할당해서 나타내준다.

# %%
import urllib.parse
url1='http://www.example.com/sample?name=홍길동&age=30'
url2='http://www.abc.com?name=홍길동&age=30'
data=urllib.parse.urlparse(url1)
print(data)
data2=urllib.parse.urlparse(url2)
print(data2)
# Out:
# ParseResult(scheme='http', netloc='www.example.com', path='/sample', params='', query='name=홍길동&age=30', fragment='')
# ParseResult(scheme='http', netloc='www.abc.com', path='', params='', query='name=홍길동&age=30', fragment='')
